# %%
class Tree:
    def __init__(self, key):
        self.right = None
        self.left  = None
        self.key   = key

# %%
root             = Tree(1)
root.left        = Tree(2)
root.right       = Tree(3)
root.left.left   = Tree(4)
root.left.right  = Tree(5)
root.right.left  = Tree(6)
root.right.right = Tree(7)

# %%
def preOrder(node):
    if(node!=None):
        print(node.key)
        preOrder(node.left)
        preOrder(node.right)

# %%
preOrder(root)
# Out:
# 1
# 2
# 4
# 5
# 3
# 6
# 7

# %%
def inOrder(node):
    if(node != None):
        inOrder(node.left)
        print(node.key)
        inOrder(node.right)

# %%
inOrder(root)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-b069b607c8b0> in <module>
# ----> 1 inOrder(root)
#
# <ipython-input-7-69fc8262b352> in inOrder(node)
#       1 def inOrder(node):
# ----> 2     inOrder(node.left)
#       3     print(node.key)
#       4     inOrder(node.right)
#
# <ipython-input-7-69fc8262b352> in inOrder(node)
#       1 def inOrder(node):
# ----> 2     inOrder(node.left)
#       3     print(node.key)
#       4     inOrder(node.right)
#
# <ipython-input-7-69fc8262b352> in inOrder(node)
#       1 def inOrder(node):
# ----> 2     inOrder(node.left)
#       3     print(node.key)
#       4     inOrder(node.right)
#
# <ipython-input-7-69fc8262b352> in inOrder(node)
#       1 def inOrder(node):
# ----> 2     inOrder(node.left)
#       3     print(node.key)
#       4     inOrder(node.right)
#
# AttributeError: 'NoneType' object has no attribute 'left'
