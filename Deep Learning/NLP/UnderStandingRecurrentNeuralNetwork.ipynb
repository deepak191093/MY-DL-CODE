# %%
import os
import re
import sys
import string
import numpy as np
import tensorflow as tf

# %%
np.set_printoptions(threshold=sys.maxsize)

# %%
inputs = np.random.random([1, 1, 10]).astype(np.float32)
simple_rnn = tf.keras.layers.SimpleRNN(12)

output = simple_rnn(inputs)  # The output has shape `[32, 4]`.

# simple_rnn = tf.keras.layers.SimpleRNN(
#     4, return_sequences=True, return_state=True)

# # whole_sequence_output has shape `[32, 10, 4]`.
# # final_state has shape `[32, 4]`.
# whole_sequence_output, final_state = simple_rnn(inputs)

# %%
simple_rnn.get_weights()

# %%
print(len(simple_rnn.get_weights()[0]), len(simple_rnn.get_weights()[1]), len(simple_rnn.get_weights()[2]))

# %%
simple_rnn.get_weights()[0]

# %%
model = tf.keras.Sequential()
# Add an Embedding layer expecting input vocab of size 1000, and
# output embedding dimension of size 64.
model.add(tf.keras.layers.Embedding(input_dim=1000, output_dim=64))

# Add a LSTM layer with 128 internal units.

# %%
model.summary()

# %%
model.predict([[1,2],[1,2]])
