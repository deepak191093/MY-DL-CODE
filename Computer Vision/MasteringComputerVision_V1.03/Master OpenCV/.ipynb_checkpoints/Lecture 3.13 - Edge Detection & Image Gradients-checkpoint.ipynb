# %% [markdown]
# ## Edge Detection & Image Gradients

# %%
import cv2
import numpy as np

image = cv2.imread('images/input.jpg', 0)
height, width = image.shape 
cv2.imshow("Orignal Image", image)
cv2.destroyAllWindows()

# Extract Sobel Edges
sobel_x = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=5) #cv2.sobel(image, ddepth, vertical, horizontal, Ksize)
sobel_y = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=5) #cv2.sobel(image, ddepth, vertical, horizontal, Ksize)

cv2.imshow('Original', image)
cv2.waitKey(0)
cv2.imshow('Sobel X', sobel_x)
cv2.waitKey(0)
cv2.imshow('Sobel Y', sobel_y)
cv2.waitKey(0)

sobel_OR = cv2.bitwise_or(sobel_x, sobel_y)
cv2.imshow('sobel_OR', sobel_OR)
cv2.waitKey(0)

sobel_and = cv2.bitwise_and(sobel_x, sobel_y)
cv2.imshow('sobel_and', sobel_and)
cv2.waitKey()

laplacian = cv2.Laplacian(image, cv2.CV_64F)
cv2.imshow('Laplacian', laplacian)
cv2.waitKey(0)

# Then, we need to provide two values: threshold1 and threshold2. Any gradient value larger than threshold2
# Is considered to be an edge. Any value below threshold1 is considered not to be an edge. 
# Values in between threshold1 and threshold2 are either classiﬁed as edges or non-edges based on how their 
# Intensities are “connected”. In this case, any gradient values below 60 are considered non-edges
# Whereas any values above 120 are considered edges.

# Canny Edge Detection uses gradient values as thresholds
# The first threshold gradient

canny = cv2.Canny(image, 50, 120)
cv2.imshow('Canny', canny)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [raw]
# #Practice

# %%
import cv2

# %%
img = cv2.imread("./images/input.jpg",0)
cv2.imshow("Orignal", img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
imgX = cv2.Sobel(img, cv2.CV_64F, 0, 1, 5)
cv2.imshow("X", imgX)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
imgY = cv2.Sobel(img, cv2.CV_64F, 1, 0 , 5)
cv2.imshow("Y", imgY)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img_or = cv2.bitwise_or(imgX, imgY)
cv2.imshow("or", img_or)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img_and = cv2.bitwise_and(imgX, imgY)
cv2.imshow("and", img_and)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img_lap = cv2.Laplacian(img, cv2.CV_64F)
cv2.imshow("Laplacian", img_lap)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
canny =  cv2.Canny(img, 0,50)
cv2.imshow("Canny", canny)
cv2.waitKey()
cv2.destroyAllWindows()
