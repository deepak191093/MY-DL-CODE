# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
sales = np.random.rand(35)

# %%
sales
# Out:
# array([0.80405266, 0.64726375, 0.84039442, 0.91449485, 0.98827841,
#        0.13372515, 0.07986299, 0.72406427, 0.03762466, 0.17593797,
#        0.50164822, 0.88915998, 0.39321212, 0.98482187, 0.99134177,
#        0.28749917, 0.75577515, 0.39970569, 0.13605588, 0.57602743,
#        0.79530594, 0.91332698, 0.8273098 , 0.57881577, 0.34742534,
#        0.37900265, 0.6681708 , 0.2504966 , 0.80181567, 0.03597387,
#        0.98485839, 0.35036173, 0.55011123, 0.43992948, 0.85322298])

# %%
profit = np.random.rand(35)

# %%
profit

# %%
plt.scatter(profit, sales)
