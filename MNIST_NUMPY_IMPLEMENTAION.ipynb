# %%
import numpy as np

# %%
class Linear():
    def __int__(self, in_size, out_size):
        self.W = np.random.rand(in_size, out_size) * 0.01
        self.b = np.zeros(1, out_size)
        self.params = [self.W,self.b]
        self.gradW  = None
        self.gardb  = None
        self.gradInput = None
    
    def Forward(self, X):
        self.X = X
        self.output = np.dot(X, self.W) + self.b
        return self.output
    
    def Backword(self)
