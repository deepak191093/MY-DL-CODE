# %%
import pandas as pd
import re

# %%
a = pd.DataFrame(["0x1234", "0xdsfsdflksdjflk", "0xdsdfdsfsdfsdf"], columns = ["a"])

# %%
a
# Out:
#                   a
# 0            0x1234
# 1  0xdsfsdflksdjflk
# 2   0xdsdfdsfsdfsdf

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
z = a["a"].map(lambda x : x.replace("0x", ""))

# %%
z
# Out:
# 0              1234
# 1    dsfsdflksdjflk
# 2     dsdfdsfsdfsdf
# Name: a, dtype: object
