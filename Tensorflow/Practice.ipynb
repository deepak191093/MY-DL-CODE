# %%
import tensorflow as tf

# %%
import pandas as pd

# %%
rank_0_tensor = tf.constant(1)

# %%
print(rank_0_tensor)
# Out:
# tf.Tensor(1, shape=(), dtype=int32)

# %%
rank_0_tensor
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=1>

# %%
rank_1_tensor = tf.constant([1, 2, 3, 4, 5])

# %%
rank_1_tensor
# Out:
# <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 2, 3, 4, 5])>

# %%
print(rank_1_tensor)
# Out:
# tf.Tensor([1 2 3 4 5], shape=(5,), dtype=int32)

# %%
rank_2_tensor = tf.constant([[1, 2, 3, 4], [1.0, 2.0, 3.0, 4.0]])

# %%
rank_2_tensor
# Out:
# <tf.Tensor: shape=(2, 4), dtype=float32, numpy=
# array([[1., 2., 3., 4.],
#        [1., 2., 3., 4.]], dtype=float32)>

# %%
print(rank_2_tensor)
# Out:
# tf.Tensor(
# [[1. 2. 3. 4.]
#  [1. 2. 3. 4.]], shape=(2, 4), dtype=float32)

# %%
rank_3_tensor = tf.constant([[[1, 2, 3], [4, 5, 6]],[[1, 2, 3], [4, 5, 6]]])

# %%
rank_3_tensor
# Out:
# <tf.Tensor: shape=(2, 2, 3), dtype=int32, numpy=
# array([[[1, 2, 3],
#         [4, 5, 6]],
#
#        [[1, 2, 3],
#         [4, 5, 6]]])>

# %%
print(rank_3_tensor)
# Out:
# tf.Tensor(
# [[[1 2 3]
#   [4 5 6]]
#
#  [[1 2 3]
#   [4 5 6]]], shape=(2, 2, 3), dtype=int32)

# %%
import numpy as np

# %%
rank_3_tensor_as_numpy = np.array(rank_3_tensor)

# %%
rank_3_tensor_as_numpy
# Out:
# array([[[1, 2, 3],
#         [4, 5, 6]],
#
#        [[1, 2, 3],
#         [4, 5, 6]]])

# %%
print(rank_3_tensor_as_numpy)
# Out:
# [[[1 2 3]
#   [4 5 6]]
#
#  [[1 2 3]
#   [4 5 6]]]

# %%
rank_3_tensor_as_numpy_1 = rank_3_tensor.numpy()

# %%
rank_3_tensor_as_numpy_1
# Out:
# array([[[1, 2, 3],
#         [4, 5, 6]],
#
#        [[1, 2, 3],
#         [4, 5, 6]]])

# %%
print(rank_3_tensor_as_numpy_1)
# Out:
# [[[1 2 3]
#   [4 5 6]]
#
#  [[1 2 3]
#   [4 5 6]]]

# %%
tf1 = tf.constant([[1, 2, 3], [4, 5, 6]])

# %%
tf2 = tf.constant([[4, 5, 6], [7, 8, 9]])

# %%
tf1
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[1, 2, 3],
#        [4, 5, 6]])>

# %%
tf2
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[4, 5, 6],
#        [7, 8, 9]])>

# %%
tf_add = tf.add(tf1, tf2)

# %%
tf_add
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[ 5,  7,  9],
#        [11, 13, 15]])>

# %%
tf_mul = tf.multiply(tf1, tf2)

# %%
tf_mul
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[ 4, 10, 18],
#        [28, 40, 54]])>

# %%
tf1 + tf2
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[ 5,  7,  9],
#        [11, 13, 15]])>

# %%
tf1 * tf2
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[ 4, 10, 18],
#        [28, 40, 54]])>

# %%
tf.matmul(tf1, tf.ones([3, 2], dtype=tf.int32))
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[ 6,  6],
#        [15, 15]])>

# %%
tf1 @ tf.ones([3, 2], dtype = tf.int32)
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[ 6,  6],
#        [15, 15]])>
