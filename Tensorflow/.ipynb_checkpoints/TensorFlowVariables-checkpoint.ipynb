# %%
import tensorflow as tf

# %% [markdown]
# # Variables are created and tracked via the tf.Variable class. A tf.Variable represents a tensor whose value can be changed by running ops on it.

# %%
# Uncomment to see where your variables get placed (see below)
# tf.debugging.set_log_device_placement(True)

# %%
my_tensor = tf.constant([[1.0, 2.0], [3.0, 4.0]])

# %%
my_tensor
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[1., 2.],
#        [3., 4.]], dtype=float32)>

# %%
my_tensor.ndim
# Out:
# 2

# %%
my_tensor.shape
# Out:
# TensorShape([2, 2])

# %%
my_variable = tf.Variable(my_tensor, name="deepak")

# %%
my_variable
# Out:
# <tf.Variable 'deepak:0' shape=(2, 2) dtype=float32, numpy=
# array([[1., 2.],
#        [3., 4.]], dtype=float32)>

# %%
my_variable.numpy()
# Out:
# array([[1., 2.],
#        [3., 4.]], dtype=float32)

# %%
constant = tf.constant([1, 2, 3, 4, 5])
variable = tf.Variable([1, 2, 3, 4, 5])

# %%
constant
# Out:
# <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 2, 3, 4, 5])>

# %%
variable
# Out:
# <tf.Variable 'Variable:0' shape=(5,) dtype=int32, numpy=array([1, 2, 3, 4, 5])>

# %%
constant = tf.constant([6, 7, 8, 9, 10])

# %%
bool_variable = tf.Variable([False, False, False, True])
complex_variable = tf.Variable([5 + 4j, 6 + 1j])

# %%
my_variable

# %%
my_variable.shape

# %%
my_variable.dtype

# %%
bool_variable.dtype

# %%
bool_variable.shape

# %%
complex_variable.dtype

# %%
complex_variable.shape
